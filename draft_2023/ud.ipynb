# %%
from ud import *

# %%
pos = get_pos_transitions('data/es_ancora-ud-train.conllu')
wfsa = construct_wfsa(pos)
wfsa
# Out:
# 14287it [00:04, 3053.02it/s]
# WFSA(19 states, <class 'rayuela.base.semiring.Real'>)
